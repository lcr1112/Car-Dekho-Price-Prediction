# %% [markdown]
# # Car Dekho Price Prediction Model using Linear Regression
# ##The main aim of this project is to predict Selling Price the car price based on various features such as Car_Name,Year,Present_Price,Kms_Driven,Fuel_Type,Seller_Type,Transmission,Owner

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\LC Ranga\AppData\Local\Temp\Temp1_Car dekho.zip\car data.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %% [markdown]
# # 1. Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# No missing values in dataset

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
sns.barplot(x='Owner',y='Selling_Price',data=df)

# %%
sns.barplot(x='Fuel_Type',y='Selling_Price',data=df)

# %%
sns.barplot(x='Transmission',y='Selling_Price',data=df)

# %%
df['Age']=2020-df['Year']
# converting year into age

# %%
sns.barplot(x='Age',y='Selling_Price',data=df)

# %%
# As vehicle gets older selling price decreases

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Car_Name',y='Selling_Price',data=df)

# %%
# there is a lots of category in Car name
# we can drop car_name.
# As Present Price plays same role.

# %%
g=df.groupby('Car_Name')

# %%
g.groups
# Out:
# {'800': Int64Index([37], dtype='int64'),
#  'Activa 3g': Int64Index([165, 196], dtype='int64'),
#  'Activa 4g': Int64Index([173], dtype='int64'),
#  'Bajaj  ct 100': Int64Index([195], dtype='int64'),
#  'Bajaj Avenger 150': Int64Index([127], dtype='int64'),
#  'Bajaj Avenger 150 street': Int64Index([141], dtype='int64'),
#  'Bajaj Avenger 220': Int64Index([126, 132, 133], dtype='int64'),
#  'Bajaj Avenger 220 dtsi': Int64Index([139, 163], dtype='int64'),
#  'Bajaj Avenger Street 220': Int64Index([160], dtype='int64'),
#  'Bajaj Discover 100': Int64Index([183], dtype='int64'),
#  'Bajaj Discover 125': Int64Index([191, 198], dtype='int64'),
#  'Bajaj Dominar 400': Int64Index([103], dtype='int64'),
#  'Bajaj Pulsar  NS 200': Int64Index([144], dtype='int64'),
#  'Bajaj Pulsar 135 LS': Int64Index([172], dtype='int64'),
#  'Bajaj Pulsar 150': Int64Index([135, 184, 190, 200], dtype='int64'),
#  'Bajaj Pulsar 220 F': Int64Index([148, 149], dtype='int64'),
# ...

# %% [markdown]
# # 2. Feature Engineering and Feature Selection
# ## converting categorical varibles into numerical

# %%
Seller_type=pd.get_dummies(df['Seller_Type'])
Transmission=pd.get_dummies(df['Transmission'])
Fuel_type=pd.get_dummies(df['Fuel_Type'])

# %%
Seller_type
# Out:
#      Dealer  Individual
# 0         1           0
# 1         1           0
# 2         1           0
# 3         1           0
# 4         1           0
# ..      ...         ...
# 296       1           0
# 297       1           0
# 298       1           0
# 299       1           0
# 300       1           0
#
# [301 rows x 2 columns]

# %%
Transmission
# Out:
#      Automatic  Manual
# 0            0       1
# 1            0       1
# 2            0       1
# 3            0       1
# 4            0       1
# ..         ...     ...
# 296          0       1
# 297          0       1
# 298          0       1
# 299          0       1
# 300          0       1
#
# [301 rows x 2 columns]

# %%
Fuel_type
# Out:
#      CNG  Diesel  Petrol
# 0      0       0       1
# 1      0       1       0
# 2      0       0       1
# 3      0       0       1
# 4      0       1       0
# ..   ...     ...     ...
# 296    0       1       0
# 297    0       0       1
# 298    0       0       1
# 299    0       1       0
# 300    0       0       1
#
# [301 rows x 3 columns]

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Age
# 0        Dealer       Manual      0    6
# ...

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner', 'Age'],
#       dtype='object')

# %%
df.drop(['Car_Name', 'Year','Fuel_Type','Seller_Type','Transmission'],axis=1,inplace=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age
# 0             3.35           5.59       27000      0    6
# 1             4.75           9.54       43000      0    7
# 2             7.25           9.85        6900      0    3
# 3             2.85           4.15        5200      0    9
# 4             4.60           6.87       42450      0    6
# ..             ...            ...         ...    ...  ...
# 296           9.50          11.60       33988      0    4
# 297           4.00           5.90       60000      0    5
# 298           3.35          11.00       87934      0   11
# 299          11.50          12.50        9000      0    3
# 300           5.30           5.90        5464      0    4
#
# [301 rows x 5 columns]

# %%
df1=pd.concat([df,Seller_type,Transmission,Fuel_type],axis=1)

# %%
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age  Dealer  Individual  \
# 0             3.35           5.59       27000      0    6       1           0
# 1             4.75           9.54       43000      0    7       1           0
# 2             7.25           9.85        6900      0    3       1           0
# 3             2.85           4.15        5200      0    9       1           0
# 4             4.60           6.87       42450      0    6       1           0
# ..             ...            ...         ...    ...  ...     ...         ...
# 296           9.50          11.60       33988      0    4       1           0
# 297           4.00           5.90       60000      0    5       1           0
# 298           3.35          11.00       87934      0   11       1           0
# 299          11.50          12.50        9000      0    3       1           0
# 300           5.30           5.90        5464      0    4       1           0
#
# ...

# %%
y=df1['Selling_Price']

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
x=df1.drop(['Selling_Price'],axis=1)

# %%
x
# Out:
#      Present_Price  Kms_Driven  Owner  Age  Dealer  Individual  Automatic  \
# 0             5.59       27000      0    6       1           0          0
# 1             9.54       43000      0    7       1           0          0
# 2             9.85        6900      0    3       1           0          0
# 3             4.15        5200      0    9       1           0          0
# 4             6.87       42450      0    6       1           0          0
# ..             ...         ...    ...  ...     ...         ...        ...
# 296          11.60       33988      0    4       1           0          0
# 297           5.90       60000      0    5       1           0          0
# 298          11.00       87934      0   11       1           0          0
# 299          12.50        9000      0    3       1           0          0
# 300           5.90        5464      0    4       1           0          0
#
#      Manual  CNG  Diesel  Petrol
# 0         1    0       0       1
# ...

# %% [markdown]
# # 3. Train Test Split, Creating &Training Model and Model Evaluation
# ## Using Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_test.head()
# Out:
#      Present_Price  Kms_Driven  Owner  Age  Dealer  Individual  Automatic  \
# 11           10.38       51000      0    5       1           0          0
# 204           4.43       28282      0    5       1           0          0
# 102           1.78        4000      0    3       0           1          0
# 201           6.79       58000      1   10       1           0          0
# 226           5.70       24678      0    5       1           0          0
#
#      Manual  CNG  Diesel  Petrol
# 11        1    0       1       0
# 204       1    0       0       1
# 102       1    0       0       1
# 201       1    0       1       0
# 226       1    0       0       1

# %%
y_test.head()
# Out:
# 11     6.85
# 204    2.75
# 102    1.65
# 201    3.25
# 226    5.25
# Name: Selling_Price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([ 8.09189496,  3.74493039,  2.36653022,  3.90588893,  4.31752492,
#         3.09843276,  2.82915216,  1.70973676, 10.0564369 ,  9.51001294,
#         3.62023662,  3.58191946,  6.46731155,  1.73871205,  5.24122035,
#         2.3384866 ,  7.56805931,  5.30007638,  1.75062281,  5.63905326,
#         8.70394377, 20.43442281, 10.12423425,  8.9082653 ,  0.81103036,
#        -0.05371894,  0.91028079,  1.52593119,  7.02518036,  3.86440973,
#         4.31324969])

# %%
model.score(x_test,y_test)
# Out:
# 0.9082179798498367

# %%
from sklearn import metrics

# %%
MAE=metrics.mean_absolute_error(y_test,y_predict)
MSE=metrics.mean_squared_error(y_test,y_predict)
R2_score=metrics.r2_score(y_test,y_predict)

# %%
print(f'MAE:{MAE}\n MSE:{MSE}\n R2_score:{R2_score}')
# Out:
# MAE:1.0764853882366048
#  MSE:1.6690961683816743
#  R2_score:0.9082179798498367

# %%
sns.distplot(y_test,color='b',label='y_test')
sns.distplot(y_predict,color='r',label='y_pred.')
plt.legend()
